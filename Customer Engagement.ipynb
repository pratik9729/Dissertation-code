# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Person

# %%
def read_files_in_folder(folder_path):
    dataframes = {}
    files = os.listdir(folder_path)
    for file in files:
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            dataframes[file] = df
        elif file.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path)
            dataframes[file] = df
    return dataframes

folder_path = ("/content/drive/MyDrive/Dissertation/CSV Data/2.Person Data")
dataframes = read_files_in_folder(folder_path)
dataframes.keys()
# Out:
# dict_keys(['anation.csv', 'apermarsts.csv', 'areligion.csv', 'asexorient.csv', 'eth.csv', 'mis_lang.csv', 'per.csv'])

# %%
dataframes["per.csv"]
# Out:
#               dob             fnam      snam   ttl     num  sex death-dat  \
# 0      19/12/1968             Mark  Brickley    Mr  254561  1.0       NaN
# 1      13/12/1982          Michael  Brickley    Mr  309664  1.0       NaN
# 2      25/10/1998          Michael  Brickley    Mr  298658  1.0       NaN
# 3      13/02/1982  Michael Stephen  Brickley    Mr  290692  1.0       NaN
# 4      19/01/1988            Nicky  Brickley    Mr  298221  1.0       NaN
# ...           ...              ...       ...   ...     ...  ...       ...
# 66040  01/01/1965              NaN  Brickley   Mrs  232202  0.0       NaN
# 66041  03/11/1990             Karl  Brickley    Mr  308697  1.0       NaN
# 66042  11/02/1995            Katie  Brickley  Miss  304531  0.0       NaN
# 66043  01/11/1987              Lee  Brickley    Mr  308696  1.0       NaN
# 66044  26/07/1967    Lorraine Rose  Brickley   Mrs  254562  0.0       NaN
#
#       eth-cde lang-cde apermarsts-cde nat-cde religion-cde sex-orientation-cde
# ...

# %%
import pandas as pd

def map_and_add_column(df, map_df, from_column, to_column, map_column , mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)


map_and_add_column(dataframes["per.csv"], dataframes["anation.csv"], "nat-cde", "nation", "dsc" ,"cde")
map_and_add_column(dataframes["per.csv"], dataframes["apermarsts.csv"], "apermarsts-cde", "martital_status", "dsc" ,"cde")
map_and_add_column(dataframes["per.csv"], dataframes["areligion.csv"], "religion-cde", "religion", "dsc" , "cde")
map_and_add_column(dataframes["per.csv"], dataframes["asexorient.csv"], "sex-orientation-cde", "sex_orientation", "dsc" , "cde")
map_and_add_column(dataframes["per.csv"], dataframes["eth.csv"], "eth-cde", "ethinicity", "dsc" , "cde")
map_and_add_column(dataframes["per.csv"], dataframes["mis_lang.csv"], "lang-cde", "language", "lang_dsc" , "lang_cde")

# %%
dataframes["per.csv"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66045 entries, 0 to 66044
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dob                  65396 non-null  object
#  1   fnam                 62715 non-null  object
#  2   snam                 66045 non-null  object
#  3   ttl                  65646 non-null  object
#  4   num                  66045 non-null  int64
#  5   sex                  66043 non-null  float64
#  6   death-dat            1076 non-null   object
#  7   eth-cde              43480 non-null  object
#  8   lang-cde             65973 non-null  object
#  9   apermarsts-cde       65970 non-null  object
#  10  nat-cde              10944 non-null  object
#  11  religion-cde         8076 non-null   object
#  12  sex-orientation-cde  7161 non-null   object
#  13  nation               10944 non-null  object
#  14  martital_status      65969 non-null  object
# ...

# %%
person = dataframes["per.csv"]

# %%
person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66045 entries, 0 to 66044
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dob                  65396 non-null  object
#  1   fnam                 62715 non-null  object
#  2   snam                 66045 non-null  object
#  3   ttl                  65646 non-null  object
#  4   num                  66045 non-null  int64
#  5   sex                  66043 non-null  float64
#  6   death-dat            1076 non-null   object
#  7   eth-cde              43480 non-null  object
#  8   lang-cde             65973 non-null  object
#  9   apermarsts-cde       65970 non-null  object
#  10  nat-cde              10944 non-null  object
#  11  religion-cde         8076 non-null   object
#  12  sex-orientation-cde  7161 non-null   object
#  13  nation               10944 non-null  object
#  14  martital_status      65969 non-null  object
# ...

# %%
person = dataframes["per.csv"]

# %%
person["year"] = person["dob"].str.split("/").str[-1].fillna(2024).astype(int)

# %%
person["present age"] = 2023- person["year"]

# %%
person["ethinicity"].fillna("Not Known" , inplace=True)

# %%
person["language"].fillna("Not stated" , inplace= True)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='ethinicity')
plt.title('Distribution of Ethnicities')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
ethnicity_counts = person['ethinicity'].value_counts()
report = pd.DataFrame({'Ethnicity': ethnicity_counts.index, 'Count': ethnicity_counts.values})
report = report.sort_values(by='Count', ascending=False)

print("Ethnicity Distribution Report:\n")
print(report)
# Out:
# Ethnicity Distribution Report:
#
#                Ethnicity  Count
# 0        WHITE / BRITISH  33124
# 1              Not Known  25633
# 2          WHITE / OTHER   1458
# 3        BLACK / AFRICAN    896
# 4      BLACK / CARIBBEAN    770
# 5          BLACK / OTHER    594
# 6                  OTHER    552
# 7       QUESTION REFUSED    486
# 8   WHITE/BLACK CARIBBEA    458
# 9          ASIAN / OTHER    404
# 10         BLACK BRITISH    360
# 11        ASIAN / INDIAN    319
# 12         WHITE / IRISH    260
# 13   ASIAN / BANGLADESHI    184
# 14     ASIAN / PAKISTANI    156
# 15  OTHER JOINT ETHNICIT    129
# 16   WHITE/BLACK AFRICAN     94
# 17               CHINESE     89
# 18         WHITE / ASIAN     79

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='language')
plt.title('Distribution by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Report
ethnicity_counts = person['language'].value_counts()
report = pd.DataFrame({'Language': ethnicity_counts.index, 'Count': ethnicity_counts.values})
report = report.sort_values(by='Count', ascending=False)

print("Language Distribution Report:\n")
print(report)
# Out:
# Language Distribution Report:
#
#        Language  Count
# 0       ENGLISH  62777
# 1         OTHER   1320
# 2    Not stated    940
# 3        Polish    163
# 4      GUJARATI    159
# 5       BENGALI    134
# 6         Czech    119
# 7       CHINESE     79
# 8   ? UNKNOWN ?     72
# 9        FRENCH     62
# 10         URDU     57
# 11       ARABIC     30
# 12       Slovak     24
# 13    PORTUGESE     23
# 14      PERSIAN     21
# 15     MANDARIN     20
# 16      ITALIAN     17
# 17      SWAHILI     13
# 18      AMHARIC      9
# 19      LINGALA      6

# %%
person["sex_orientation"].fillna("Not known" , inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='sex_orientation')
plt.title('Distribution ')
plt.xlabel('Sex orientaion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Report
ethnicity_counts = person['sex_orientation'].value_counts()
report = pd.DataFrame({'Sex orientation': ethnicity_counts.index, 'Count': ethnicity_counts.values})
report = report.sort_values(by='Count', ascending=False)

print(" Distribution Report:\n")
print(report)
# Out:
#  Distribution Report:
#
#     Sex orientation  Count
# 0         Not known  58884
# 1      Heterosexual   5836
# 2  Question Refused   1145
# 3       Gay/Lesbian     73
# 4          Bisexual     53
# 5             Other     47
# 6        Transexual      7

# %%
person
# Out:
#               dob             fnam      snam   ttl     num  sex death-dat  \
# 0      19/12/1968             Mark  Brickley    Mr  254561  1.0       NaN
# 1      13/12/1982          Michael  Brickley    Mr  309664  1.0       NaN
# 2      25/10/1998          Michael  Brickley    Mr  298658  1.0       NaN
# 3      13/02/1982  Michael Stephen  Brickley    Mr  290692  1.0       NaN
# 4      19/01/1988            Nicky  Brickley    Mr  298221  1.0       NaN
# ...           ...              ...       ...   ...     ...  ...       ...
# 66040  01/01/1965              NaN  Brickley   Mrs  232202  0.0       NaN
# 66041  03/11/1990             Karl  Brickley    Mr  308697  1.0       NaN
# 66042  11/02/1995            Katie  Brickley  Miss  304531  0.0       NaN
# 66043  01/11/1987              Lee  Brickley    Mr  308696  1.0       NaN
# 66044  26/07/1967    Lorraine Rose  Brickley   Mrs  254562  0.0       NaN
#
#       eth-cde lang-cde apermarsts-cde  ... religion-cde sex-orientation-cde  \
# ...

# %%
person["nation"].fillna("Not known" , inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='nation')
plt.title('Distribution ')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Report
counts = person['nation'].value_counts()
report = pd.DataFrame({'Nationality': counts.index, 'Count': counts.values})
report = report.sort_values(by='Count', ascending=False)

print(" Distribution Report:\n")
print(report)
# Out:
#  Distribution Report:
#
#                   Nationality  Count
# 0                   Not known  55101
# 1   UK National resident in U   9914
# 2           Any Other Country    423
# 3                      Poland    229
# 4    Other Euro Economic Area    128
# 5              Czech Republic    111
# 6   UK Nat'l ret from Oversea     67
# 7                    Slovakia     45
# 8                   Lithuania     13
# 9                     Estonia      7
# 10                     Latvia      4
# 11                    Hungary      2
# 12                   Slovenia      1

# %%
person["religion"].fillna("Not known" , inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='religion')
plt.title('Distribution ')
plt.xlabel('Religion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Report
counts = person['religion'].value_counts()
report = pd.DataFrame({'Religion': counts.index, 'Count': counts.values})
report = report.sort_values(by='Count', ascending=False)

print(" Distribution Report:\n")
print(report)
# Out:
#  Distribution Report:
#
#              Religion  Count
# 0           Not known  57970
# 1           Christian   3766
# 2         No Religion   2736
# 3          Not Stated    487
# 4    Question Refused    336
# 5            Catholic    244
# 6               Other    225
# 7              Muslim    210
# 8   Jehovah's Witness     18
# 9           Methodist     17
# 10           Buddhist     17
# 11              Hindu     10
# 12             Jewish      7
# 13               Sikh      2

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=person, x='martital_status')
plt.title('Distribution ')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Report
counts = person['martital_status'].value_counts()
report = pd.DataFrame({'Marital Status': counts.index, 'Count': counts.values})
report = report.sort_values(by='Count', ascending=False)

print(" Distribution Report:\n")
print(report)
# Out:
#  Distribution Report:
#
#   Marital Status  Count
# 0     NOT STATED  33071
# 1         SINGLE  19318
# 2        MARRIED   7465
# 3       DIVORCED   1619
# 4     COMMON-LAW   1327
# 5      SEPARATED   1304
# 6        WIDOWED   1130
# 7        ENGAGED    647
# 8     CIVIL P'TR     88

# %% [markdown]
# # Property

# %%
def read_files_in_folder(folder_path):
    dataframes = {}
    files = os.listdir(folder_path)
    for file in files:
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            dataframes[file] = df
        elif file.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path)
            dataframes[file] = df
    return dataframes

folder_path = ("/content/drive/MyDrive/Dissertation/CSV Data/1.Property")
dataframes = read_files_in_folder(folder_path)
dataframes.keys()
# Out:
# dict_keys(['aprstyle.csv', 'pr.csv', 'prcls.csv', 'prtype.csv', 'str.csv'])

# %%
import pandas as pd


def map_and_add_column(df, map_df, from_column, to_column, map_column,
                       mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)


map_and_add_column(dataframes["pr.csv"], dataframes["prcls.csv"], "prcls-cde",
                   "Property Class", "dsc", "cde")
map_and_add_column(dataframes["pr.csv"], dataframes["prtype.csv"], "prtyp-cde",
                   "Property Type", "dsc", "cde")
map_and_add_column(dataframes["pr.csv"], dataframes["str.csv"], "str-cde",
                   "Loc Code", "loc-cde", "cde")
map_and_add_column(dataframes["pr.csv"], dataframes["str.csv"], "str-cde",
                   "Location", "nam", "cde")

# %%
dataframes["pr.csv"]
# Out:
#      prcls-cde  seq-no  co-own postcode rtb-dat demolish-dat  str-cde  \
# 0            H   10000       1  GL2 4YR     NaN   27/03/1995        2
# 1            S   17468       1      NaN     NaN          NaN        2
# 2            H   10001       1  GL3 1LR     NaN   03/04/1995        5
# 3            S   17474       1      NaN     NaN          NaN        5
# 4            H   10002       1  GL3 2RU     NaN   25/06/1995        6
# ...        ...     ...     ...      ...     ...          ...      ...
# 8575         H   18590       1  GL2 5LZ     NaN          NaN     9947
# 8576         B   18591       1  GL2 5LZ     NaN          NaN     9947
# 8577         F   18592       0  GL2 5LZ     NaN          NaN     9947
# 8578         F   18593       0  GL2 5LZ     NaN          NaN     9947
# 8579         S   18594       0  GL5 1DR     NaN          NaN     9951
#
#      prtyp-cde  construction-yr  \
# 0       1BB 00           1900.0
# 1          ZZS              NaN
# ...

# %%
prop = dataframes["pr.csv"]

# %%
prop["construction-yr"].replace(0, np.nan, inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=prop, x='construction-yr', bins=20, kde=True)
plt.title('Distribution of Building Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
prop["construction-yr"].fillna(2024 , inplace=True)
prop["Property Age"] = 2023 - prop["construction-yr"]

# %%
prop
# Out:
#      prcls-cde  seq-no  co-own postcode rtb-dat demolish-dat  str-cde  \
# 0            H   10000       1  GL2 4YR     NaN   27/03/1995        2
# 1            S   17468       1      NaN     NaN          NaN        2
# 2            H   10001       1  GL3 1LR     NaN   03/04/1995        5
# 3            S   17474       1      NaN     NaN          NaN        5
# 4            H   10002       1  GL3 2RU     NaN   25/06/1995        6
# ...        ...     ...     ...      ...     ...          ...      ...
# 8575         H   18590       1  GL2 5LZ     NaN          NaN     9947
# 8576         B   18591       1  GL2 5LZ     NaN          NaN     9947
# 8577         F   18592       0  GL2 5LZ     NaN          NaN     9947
# 8578         F   18593       0  GL2 5LZ     NaN          NaN     9947
# 8579         S   18594       0  GL5 1DR     NaN          NaN     9951
#
#      prtyp-cde  construction-yr  \
# 0       1BB 00           1900.0
# 1          ZZS           2024.0
# ...

# %%
def fill_existing_building_age(row):
    if pd.notna(row["demolish-dat"]):
        return np.nan
    else:
        return row["Property Age"]
prop["existing building age"] = prop.apply(fill_existing_building_age, axis=1)

# %%
age_exist = prop["existing building age"].tolist()

# %%
prop
# Out:
#      prcls-cde  seq-no  co-own postcode rtb-dat demolish-dat  str-cde  \
# 0            H   10000       1  GL2 4YR     NaN   27/03/1995        2
# 1            S   17468       1      NaN     NaN          NaN        2
# 2            H   10001       1  GL3 1LR     NaN   03/04/1995        5
# 3            S   17474       1      NaN     NaN          NaN        5
# 4            H   10002       1  GL3 2RU     NaN   25/06/1995        6
# ...        ...     ...     ...      ...     ...          ...      ...
# 8575         H   18590       1  GL2 5LZ     NaN          NaN     9947
# 8576         B   18591       1  GL2 5LZ     NaN          NaN     9947
# 8577         F   18592       0  GL2 5LZ     NaN          NaN     9947
# 8578         F   18593       0  GL2 5LZ     NaN          NaN     9947
# 8579         S   18594       0  GL5 1DR     NaN          NaN     9951
#
#      prtyp-cde  construction-yr  \
# 0       1BB 00           1900.0
# 1          ZZS           2024.0
# ...

# %%
prop_class_counts = prop['Property Class'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=prop_class_counts.index, y=prop_class_counts, palette='viridis')
plt.title('Property Class Distribution')
plt.xlabel('Property Class')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

prop_class_percentage = (prop_class_counts / prop_class_counts.sum()) * 100
print("Property Class Distribution (Percentage):\n")
print(prop_class_percentage)
# Out:
# Property Class Distribution (Percentage):
#
# House          45.745921
# Flat           32.144522
# Garage         11.235431
# Block           6.025641
# Street          4.347319
# Commercial      0.314685
# Virtual         0.116550
# Public Bldg     0.069930
# Name: Property Class, dtype: float64

# %%
prop_class_counts = prop['Property Type'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=prop_class_counts.index, y=prop_class_counts, palette='viridis')
plt.title('Property Type Distribution')
plt.xlabel('Property Type')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

prop_class_percentage = (prop_class_counts / prop_class_counts.sum()) * 100
print("Property Types Distribution (Percentage):\n")
print(prop_class_percentage)
# Out:
# Property Types Distribution (Percentage):
#
# 3 BED SEMI-DETACHED HOUSE         17.976166
# GARAGE                            14.401131
# Block                             10.078772
# Street                             6.988487
# 1 BED FLAT 1ST FLOOR               6.140174
# 1 BED FLAT GROUND FLOOR            5.695819
# PARKING SPACE                      4.887901
# 2 BED FLAT 1ST FLOOR               3.534639
# 2 BED SEMI-DETACHED HOUSE          3.393254
# 3 BED TERRACED HOUSE               3.292264
# 2 BED FLAT GROUND FLOOR            3.130681
# 2 BED TERRACED HOUSE               3.110483
# ROOM WITHIN A HOUSE                1.636033
# STUDIO APARTMENT - 1ST FLOOR       1.555241
# 2 BED FLAT 2ND FLOOR               1.312866
# 2 BED BUNGALOW                     1.272470
# 4 BED SEMI-DETACHED HOUSE          1.211876
# 1 BED BUNGALOW                     1.211876
# STUDIO APARTMENT - 2ND FLOOR       1.090689
# 1 BED FLAT 2ND FLOOR               1.090689
# ...

# %%
prop_class_counts = prop['Loc Code'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=prop_class_counts.index, y=prop_class_counts, palette='viridis')
plt.title('Location Code Distribution')
plt.xlabel('Loc Code')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

prop_class_percentage = (prop_class_counts / prop_class_counts.sum()) * 100
print("Loc Codes Distribution (Percentage):\n")
print(prop_class_percentage)
# Out:
# Loc Codes Distribution (Percentage):
#
# MAT    20.796357
# GLO    12.494162
# TUF    10.614199
# POD     7.122840
# KIN     6.620738
# WHI     6.445586
# WES     5.896777
# CON     5.231200
# TRE     4.086875
# HOL     4.051845
# ELM     2.907520
# OVA     2.533863
# HUC     2.498832
# ROB     1.856609
# QUE     1.646427
# ABB     1.506305
# BKW     0.782345
# HWK     0.467071
# MAI     0.303596
# HEM     0.291920
# HIG     0.233536
# WIT     0.233536
# CNM     0.210182
# LRD     0.210182
# LON     0.175152
# BAR     0.163475
# WTM     0.116768
# LNG     0.105091
# TWY     0.093414
# HOR     0.081738
# STO     0.070061
# CHU     0.070061
# GAR     0.058384
# ABY     0.023354
# Name: Loc Code, dtype: float64

# %% [markdown]
# # Tenancy

# %%
def read_files_in_folder(folder_path):
    dataframes = {}
    files = os.listdir(folder_path)
    for file in files:
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            dataframes[file] = df
        elif file.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path)
            dataframes[file] = df
    return dataframes

folder_path = ("/content/drive/MyDrive/Dissertation/CSV Data/3.Tenancy")
dataframes = read_files_in_folder(folder_path)
dataframes.keys()
# Out:
# dict_keys(['mis_adisabil.csv', 'mis_arrrecgrp.csv', 'mis_rntpaymd.csv', 'mis_tncy.csv', 'mis_tncyreacde.csv', 'mis_ttncytyp.csv'])

# %%
def map_and_add_column(df, map_df, from_column, to_column, map_column , mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)

map_and_add_column(dataframes["mis_tncy.csv"], dataframes["mis_adisabil.csv"], "adisabil_cde", "Disablility", "adisabil_dsc" ,"adisabil_cde")
map_and_add_column(dataframes["mis_tncy.csv"], dataframes["mis_rntpaymd.csv"], "rntpaymd_cde", "payment mode", "rntpaymd_dsc" ,"rntpaymd_cde")
map_and_add_column(dataframes["mis_tncy.csv"], dataframes["mis_tncyreacde.csv"], "tncy_reason_cde", "Reason", "tncyreacde_dsc" , "tncyreacde_cde")
map_and_add_column(dataframes["mis_tncy.csv"], dataframes["mis_arrrecgrp.csv"], "main_arrrecgrp_cde", "Arrerers", "arrrecgrp_dsc" , "arrrecgrp_cde")
map_and_add_column(dataframes["mis_tncy.csv"], dataframes["mis_ttncytyp.csv"], "ttncytyp_cde", "Type", "ttncytyp_dsc" , "ttncytyp_cde")

# %%
tenacy = dataframes["mis_tncy.csv"]
tenacy
# Out:
#        occ_num  per_num  pr_seq_no tenu_cde    comm_dat  tncy_reason_cde  \
# 0        10000   100001      16328       CT  05/10/1981              NaN
# 1        10004   100041      14809       CT  28/07/1980              NaN
# 2        10007   100071      10057       PP  23/12/1985              NaN
# 3        10008   100081      10051       CT  18/04/1983              NaN
# 4        10009   100091      10030       ET  05/04/1976              NaN
# ...        ...      ...        ...      ...         ...              ...
# 41440    67177   340587      15507       SS  20/06/2023              0.0
# 41441    67178        1      18423       ST  26/06/2023              NaN
# 41442    67179        1      10908       CT  19/06/2023              NaN
# 41443    67180        1      12082       CT  19/06/2023              NaN
# 41444    67181        1      18465       TM  22/06/2023              NaN
#
#          term_dat rntpaymd_cde main_arrrecgrp_cde ttncytyp_cde adisabil_cde  \
# ...

# %%
tenacy["Disablility"].value_counts()
# Out:
# ? UNKNOWN ?                      41174
# Mobility Problems                   85
# Hidden Other (see OTHDIV UDC)       45
# Mental Health                       37
# Learning Disability                 31
# Physical Disability                 23
# Other (see OTHDIV UDC)              22
# Hearing Impairment                  10
# Wheelchair User                     10
# Sight Impairment                     7
# Sensory Impairment                   1
# Name: Disablility, dtype: int64

# %%
tenacy["year"] = tenacy["comm_dat"].str.split("/").str[-1]

# %%
tenacy["year"] = tenacy["year"].astype(int)

# %%
min_year = tenacy['year'].min()
max_year = tenacy['year'].max()

num_bins = 50
bin_width = (max_year - min_year) / num_bins

# Create a histogram using Matplotlib
plt.hist(tenacy['year'], bins=num_bins, range=(min_year, max_year), edgecolor='k', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Distribution of Years')
plt.grid(True)
plt.show()

# %%
counts = tenacy['payment mode'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts, palette='viridis')
plt.title('Payment Distribution Distribution')
plt.xlabel('Modes')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

percentage = (counts / counts.sum()) * 100
print("Paymenyt Mode Distribution (Percentage):\n")
print(percentage)
# Out:
# Paymenyt Mode Distribution (Percentage):
#
# ? UNKNOWN ?                       59.954156
# CASH PAYMENT                      20.106165
# FULL HOUSING BENEFIT               6.410906
# DD Monthly - due 1st to 8th        2.847147
# STANDING ORDER                     1.693811
# Alternative Payment Arrt (UC)      1.387381
# CASH PAYERS - MONTHLY              1.322234
# DIRECT DEBITS - MONTHLY            1.307757
# Direct Debit Weekly                1.085776
# DD Monthly - due 25th to 31st      0.972373
# DD Monthly - due 9th to 16th       0.764869
# DD Monthly - due 17th to 24th      0.697310
# Partial Housing Benefit            0.304017
# Direct Debit 4 Weekly              0.287128
# Direct Debit Fortnight             0.209917
# DIRECTDEBIT EVERY WK & GARAGES     0.197853
# DIRECT DEBIT WEEKLY (48WKS)        0.149596
# UC Third party Deductions          0.094101
# Recurring Card Payment - Mth       0.055495
# MyGCH Online                       0.055495
# ...

# %%
counts = tenacy['Type'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts, palette='viridis')
plt.title('Tenancy Distribution')
plt.xlabel('Tenacy')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

percentage = (counts / counts.sum()) * 100
print("Type Distribution (Percentage):\n")
print(percentage)
# Out:
# Type Distribution (Percentage):
#
# Former Tenant     48.826155
# Former Void       38.113162
# Current Tenant    11.588853
# Lettable Void      1.471830
# Name: Type, dtype: float64

# %% [markdown]
# # Complaints

# %%
complaints = pd.read_excel("/content/drive/MyDrive/Dissertation/CSV Data/5.Complaints/Complaints.xlsx")

# %%
complaints
# Out:
#     Date received Method Received \n(select from dropdown list)  \
# 0      2023-04-03                                       Writing
# 1      2023-04-04                                       On-line
# 2      2023-04-04                                         Phone
# 3      2023-04-04                                         Email
# 4      2023-04-05                                         Email
# ..            ...                                           ...
# 385           NaT                                           NaN
# 386           NaT                                           NaN
# 387           NaT                                           NaN
# 388           NaT                                           NaN
# 389           NaT                                           NaN
#
#     Date acknowledged Dated logged on CRM \n(by Governance Team)  \
# 0          2023-04-04                        2023-04-04 00:00:00
# ...

# %%
complaints.isnull().sum()
# Out:
# Date received                                                                                                                                                  319
# Method Received \n(select from dropdown list)                                                                                                                  319
# Date acknowledged                                                                                                                                              324
# Dated logged on CRM \n(by Governance Team)                                                                                                                     324
# Complaint no                                                                                                                                                     0
# Complainant Name                                                                                                                                               319
# ...

# %%
complaints["Method Received \n(select from dropdown list)"].fillna("Unknown" , inplace=True)

# %%
counts =complaints["Method Received \n(select from dropdown list)"].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts, palette='viridis')
plt.title('Method Received  Distribution')
plt.xlabel('Method Received')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

percentage = (counts / counts.sum()) * 100
print("Reason of Tenacy Distribution (Percentage):\n")
print(percentage)
# Out:
# Reason of Tenacy Distribution (Percentage):
#
# Unknown    81.794872
# On-line     7.692308
# Phone       4.871795
# Email       4.615385
# Writing     1.025641
# Name: Method Received \n(select from dropdown list), dtype: float64

# %% [markdown]
# # ASB-Anti Social Behaviour

# %%
asb= pd.read_excel("/content/drive/MyDrive/Dissertation/CSV Data/6.ASB-Anti Social Behaviour/ASB.xlsx")

# %%
asb
# Out:
#       Case_HistoryID  Case_ID            Type Current_Status       Case_Owner  \
# 0                  1        1           Noise         Closed     Lydia Jarvis
# 1                  2        3  Domestic Abuse         Closed   Loretta Sadler
# 2                  3        4           Crime         Closed   Loretta Sadler
# 3                  4        5           Noise         Closed     Lydia Jarvis
# 4                  5        7           Noise         Closed      Sarah Wilce
# ...              ...      ...             ...            ...              ...
# 4938            4939     8369  Domestic Abuse         Closed      Claire Long
# 4939            4940     8370           Drugs         Active  Chloe Etheridge
# 4940            4941     8372  Domestic Abuse         Active      Claire Long
# 4941            4942     8373  Domestic Abuse         Active     Lydia Jarvis
# 4942            4943     8374             NaN         Active     Lydia Jarvis
#
# ...

# %%
asb.isnull().sum()
# Out:
# Case_HistoryID                 0
# Case_ID                        0
# Type                          42
# Current_Status                 0
# Case_Owner                    14
# Date_Opened                    1
# Date_Closed                  106
# Complainant_Tenancy_Ref     2060
# Perpetrator_Tenancy_Ref     1998
# Complainant2_Tenancy_Ref    4624
# Perpetrator2_Tenancy_Ref    4579
# Case_Priority                 18
# dtype: int64

# %%
counts =asb["Type"].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts, palette='viridis')
plt.title('Type of ASB  Distribution')
plt.xlabel('Type ')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

percentage = (counts / counts.sum()) * 100
print("Type of ASB Distribution (Percentage):\n")
print(percentage)
# Out:
# Type of ASB Distribution (Percentage):
#
# Noise                26.341563
# Intimidation         15.527443
# Domestic Abuse       14.874515
# Drugs                14.527647
# Verbal Abuse          6.121200
# Crime                 5.692716
# Estate Management     4.631708
# Violence              4.468476
# Communal Area         3.835952
# Hate Crime            1.917976
# Alcohol               1.815956
# Race                  0.244848
# Name: Type, dtype: float64

# %%
counts = asb["Case_Priority"].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts, palette='viridis')
plt.title('Case Priority Distribution')
plt.xlabel('Case Priority')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

percentage = (counts / counts.sum()) * 100
print("Case Priority Distribution (Percentage):\n")
print(percentage)
# Out:
# Case Priority Distribution (Percentage):
#
# Serious    78.213198
# Minor      21.786802
# Name: Case_Priority, dtype: float64

# %%
asb["time taken"] = asb["Date_Closed"] - asb["Date_Opened"]

# %%
asb['time taken']
# Out:
# 0       425 days
# 1        43 days
# 2        41 days
# 3      1187 days
# 4        60 days
#           ...
# 4938      3 days
# 4939         NaT
# 4940         NaT
# 4941         NaT
# 4942         NaT
# Name: time taken, Length: 4943, dtype: timedelta64[ns]

# %%
# Assuming you have a DataFrame named 'asb' with columns 'Date_Opened' and 'Date_Closed'
asb['Date_Opened'] = pd.to_datetime(asb['Date_Opened'])
asb['Date_Closed'] = pd.to_datetime(asb['Date_Closed'])

# 1. Case Duration
asb['Case_Duration'] = (asb['Date_Closed'] - asb['Date_Opened']).dt.days
asb["Case_Duration"].fillna(-1 , inplace=True)
average_duration = asb['Case_Duration'].mean()
print(f'Average Case Duration: {average_duration} days')

# 3. Trends Over Time - Cases Opened
asb['Year_Month_Opened'] = asb['Date_Opened'].dt.to_period('M')
opened_counts = asb['Year_Month_Opened'].value_counts().sort_index()

# Convert the index and values to numeric
opened_counts.index = opened_counts.index.to_timestamp()
opened_counts = opened_counts.astype(int)

plt.figure(figsize=(10, 6))
sns.lineplot(x=opened_counts.index, y=opened_counts.values)
plt.title('Cases Opened Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()


# 4. Trends Over Time - Cases Closed
asb['Year_Month_Closed'] = asb['Date_Closed'].dt.to_period('M')
closed_counts = asb['Year_Month_Closed'].value_counts().sort_index()

# Convert the index and values to integers
closed_counts.index = closed_counts.index.to_timestamp()
closed_counts = closed_counts.astype(int)

plt.figure(figsize=(10, 6))
sns.lineplot(x=closed_counts.index, y=closed_counts.values)
plt.title('Cases Closed Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()


# 5. SLA Compliance
sla_duration = pd.to_timedelta('5 days')  # Example SLA duration

# Create a Boolean Series indicating whether each case meets the SLA criteria
within_sla = (asb['Date_Closed'] - asb['Date_Opened']) <= sla_duration
# Out:
# Average Case Duration: 230.47157596601255 days

# %%
plt.figure(figsize=(10, 6))
sns.histplot(asb['Case_Duration'], bins=20, kde=True)
plt.title('Distribution of Case Durations')
plt.xlabel('Case Duration (days)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Repairs

# %%
def read_files_in_folder(folder_path):
    dataframes = {}
    files = os.listdir(folder_path)
    for file in files:
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            dataframes[file] = df
        elif file.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path)
            dataframes[file] = df
    return dataframes

folder_path = ("/content/drive/MyDrive/Dissertation/CSV Data/4.Repairs")
dataframes = read_files_in_folder(folder_path)
dataframes.keys()
# Out:
# <ipython-input-63-ee6fad8fd796>:7: DtypeWarning: Columns (4,10,11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# dict_keys(['contr.csv', 'job.csv', 'jobdet.csv', 'jobevt.csv', 'jobevtcde.csv', 'jobevtcls.csv', 'jobsts.csv', 'pty.csv', 'SORCode.csv', 'sortrd.csv'])

# %%
import pandas as pd
def map_and_add_column(df, map_df, from_column, to_column, map_column,
                       mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)


map_and_add_column(dataframes["jobevt.csv"], dataframes["jobevtcde.csv"],
                   "cde", "Event Description", "dsc", "cde")
map_and_add_column(dataframes["jobevt.csv"], dataframes["jobevtcls.csv"],
                   "jobevtcls-cde", "Class Description", "dsc", "cde")

# %%
dataframes["jobevt.csv"]
# Out:
#          cde     num  seq-no         dat jobevtcls-cde  \
# 0        422  562821      11  14/02/2012           SYS
# 1        100  562821      12  14/02/2012           IFC
# 2        300  562821      13  14/02/2012           SYS
# 3          0  562822       1  14/02/2012           SYS
# 4         40  562822       2  14/02/2012           SYS
# ...      ...     ...     ...         ...           ...
# 1048570  200  288873       9  07/02/2006           SYS
# 1048571   61  288873      10  07/02/2006           SYS
# 1048572  260  288873      11  08/02/2006           SYS
# 1048573   61  288873      12  08/02/2006           SYS
# 1048574  270  288873      13  08/02/2006           SYS
#
#                      Event Description        Class Description
# 0                   JOB TICKET PRINTED             SYSTEM CODES
# 1                         TESTING USER  LOVELL INTERFACE EVENTS
# 2             Non tenant-raised Repair             SYSTEM CODES
# ...

# %%
import pandas as pd
def map_and_add_column(df, map_df, from_column, to_column, map_column,
                       mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)


map_and_add_column(dataframes["jobdet.csv"], dataframes["SORCode.csv"],
                   "num", "Short Description", "ShortDescription", "SORCode")
map_and_add_column(dataframes["jobdet.csv"], dataframes["SORCode.csv"],
                   "sor-num", "Description", "Description", "SORCode")

# %%
dataframes["jobdet.csv"]
# Out:
#          sor-seq-no     num sortrd-cde  sor-num Short Description Description
# 0                 1  189701          E      405               NaN         NaN
# 1                 1  189702          P      987               NaN         NaN
# 2                 2  189702          D      315               NaN         NaN
# 3                 1  189703         PD     1200               NaN         NaN
# 4                 2  189703         PD     1203               NaN         NaN
# ...             ...     ...        ...      ...               ...         ...
# 1048570          19  379327         0C      912               NaN         NaN
# 1048571          20  379327         NS     2723               NaN         NaN
# 1048572          21  379327         0E     2415               NaN         NaN
# 1048573          22  379327         0E     2356               NaN         NaN
# 1048574          23  379327         0E     2364               NaN         NaN
#
# [1048575 rows x 6 columns]

# %%
import pandas as pd
def map_and_add_column(df, map_df, from_column, to_column, map_column,
                       mapped_column):
    mapping = map_df.set_index(mapped_column)[map_column].to_dict()
    df[to_column] = df[from_column].map(mapping)


map_and_add_column(dataframes["job.csv"], dataframes["SORCode.csv"],
                   "num", "Short Description", "ShortDescription", "SORCode")
map_and_add_column(dataframes["jobdet.csv"], dataframes["SORCode.csv"],
                   "sor-num", "Description", "Description", "SORCode")

# %%
dataframes["job.csv"]
# Out:
#              num  pr-seq-no sortrd-cde-1  void-num jobsts-cde pty-cde  \
# 0              1      10257            G         0         70       2
# 1              1      10333           GF         0         90       B
# 2              2      15730           MI         0         90       W
# 3              2      15584            W         0         90     NaN
# 4              3      16862            W         0         70       5
# ...          ...        ...          ...       ...        ...     ...
# 829064    938603      16971           0B         0         2G       R
# 829065    938604      13267           0P         0         30       U
# 829066    938605      17025           0E         0         30       R
# 829067    938606      13306           DR         0         2G       R
# 829068  99999999      13687            P         0         90       0
#
#        practical-completion-dat reported-dat  contr-cde overall-target-dat  \
# ...

# %%
pty_data = pd.read_csv("/content/drive/MyDrive/Dissertation/CSV Data/4.Repairs/pty.csv")

# %%
job_data = pd.read_csv("/content/drive/MyDrive/Dissertation/CSV Data/4.Repairs/job.csv")
# Out:
# <ipython-input-71-ad38bf8574f7>:1: DtypeWarning: Columns (4,10,11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   job_data = pd.read_csv("/content/drive/MyDrive/Dissertation/CSV Data/4.Repairs/job.csv")

# %%
merged_property_data = job_data.merge(pty_data, left_on="pty-cde", right_on="pty_cde", how="left")
jobs_per_property = merged_property_data["pty_dsc"].value_counts()
plt.figure(figsize=(12, 9))
sns.barplot(x=jobs_per_property.values, y=jobs_per_property.index, palette="cividis")
plt.title("Distribution of Jobs Across Different Property Types")
plt.xlabel("Number of Jobs")
plt.ylabel("Property Type")
plt.tight_layout()
plt.show()

# %%
contr_data = pd.read_csv("/content/drive/MyDrive/Dissertation/CSV Data/4.Repairs/contr.csv")

# %%
merged_contractor_data = job_data.merge(contr_data, left_on="contr-cde", right_on="cde", how="left")
merged_contractor_data["nam"].value_counts().head(10)
# Out:
# XXX GLOUCESTER CITY SERVICES      242168
# GCH Repairs Team                  168871
# Lovell Respond                    160643
# XXX Morrison FS                    91745
# Enterprise                         11864
#  PPG (formerly Kalon)              11475
# SLATTER ELECTRICAL                  8572
# XXX GLOUCESTER HANDPERSON SERV      8547
# XXX GLOUCESTER HOUSING SERVICE      8406
# Hentland                            8012
# Name: nam, dtype: int64
